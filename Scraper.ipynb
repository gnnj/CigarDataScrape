# %%
# Import Dependencies
import pandas as pd
from splinter import Browser
from bs4 import BeautifulSoup
import pymongo

# %%
# Path to chromedriver
# !which chromedriver
# Out:
# /usr/local/bin/chromedriver

# %%
# Set the executable path and initialize the chrome browser in splinter
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
# Visit stogierate.com
url = 'https://www.stogierate.com/Cigars'
browser.visit(url)

# Wait for page to load
browser.is_element_present_by_css("ul.item_list li.slide", wait_time=1)
# Out:
# False

# %%
html = browser.html
news_soup = BeautifulSoup(html, 'html.parser')

slide_elem = news_soup.select_one('ul.item_list li.slide')

# %%
news_soup
# Out:
# <!DOCTYPE html>
# <html lang="en" prefix="og: http://ogp.me/ns#" xmlns="http://www.w3.org/1999/xhtml"><head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Browse all cigar brands</title>
# <meta content="Tue, 20 Aug 2000 9:45:00 GMT" http-equiv="Expires"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="Browse StogieRate.com's directory of cigar brands" name="description"/>
# <meta content="StogieRate.com" name="author"/>
# <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/manifest.json" rel="manifest"/>
# <link color="#5bbad5" href="/safari-pinned-tab.svg" rel="mask-icon"/>
# <link href="/css/shared?v=2K1TC6-rw8ol6CRQe3EXOF3l1F1TP37aTNC8lvbdMLM1" rel="stylesheet"/>
# <link href="/css/site?v=NKx-G5tw73FLjl_yA-93U2Qz7txjzz-l0zskMMIaIKA1" rel="stylesheet"/>
# <style type="text/css">
#         html {
#         }
#
#         body {
#             background-image: url("https://d8e2s4jrdbvb2.cloudfront.net/Images/Skin1/bg_dark.jpg");
#             background-repeat: repeat;
#             padding-top: 70px;
#         }
#
#         .srPageHeader {
#             background-color: #000000;
#         }
#     </style>
# <script async="" src="https://ssl.google-analytics.com/ga.js" type="text/javascript"></script><script type="text/javascript">
#         window.SR = ('undefined' === typeof (SR) || !SR) ? {} : SR;
#         SR_redirToLogin = function (id) { if (id) { window.location.href = '/SignIn?id=' + encodeURIComponent(id); } else { window.location.href = '/SignIn'; } };
#         SR_onStartup = [];
#         SR_onStartup.push(function () {
#             SR.html5PlaceHolders();
#         });
#
#         SR.appendStartup = function (fn) {
#             SR_onStartup.push(fn);
#         };
#     </script>
# <script type="text/javascript">
#             var _gaq = _gaq || [];
#             _gaq.push(['_setAccount', 'UA-20999103-1']);
#             _gaq.push(['_trackPageview']);
#
#             (function () {
#                 var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#                 ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#                 var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#             })();
#         </script>
# <!--[if lt IE 9]>
#         <script src="/bundle/legacyie?v=Z2_-IxrEl5wPnsqoUmIpGS0ChPmB7Z_EmmVIwxHLg8U1"></script>
#
#     <![endif]-->
# <script type="text/javascript">
#         var appInsights=window.appInsights||function(config)
#         {
#             function r(config){ t[config] = function(){ var i = arguments; t.queue.push(function(){ t[config].apply(t, i)})} }
#             var t = { config:config},u=document,e=window,o='script',s=u.createElement(o),i,f;for(s.src=config.url||'//az416426.vo.msecnd.net/scripts/a/ai.0.js',u.getElementsByTagName(o)[0].parentNode.appendChild(s),t.cookie=u.cookie,t.queue=[],i=['Event','Exception','Metric','PageView','Trace','Ajax'];i.length;)r('track'+i.pop());return r('setAuthenticatedUserContext'),r('clearAuthenticatedUserContext'),config.disableExceptionTracking||(i='onerror',r('_'+i),f=e[i],e[i]=function(config, r, u, e, o) { var s = f &amp;&amp; f(config, r, u, e, o); return s !== !0 &amp;&amp; t['_' + i](config, r, u, e, o),s}),t
#         }({
#             instrumentationKey:'ab3b2f37-0f31-41ce-8323-0b8e5b5cef32'
#         });
#
#         window.appInsights=appInsights;
#         appInsights.trackPageView();
#     </script><script src="//az416426.vo.msecnd.net/scripts/a/ai.0.js"></script>
# <style></style></head>
# <body><div aria-describedby="cookieconsent:desc" aria-label="cookieconsent" aria-live="polite" class="cc-window cc-banner cc-type-info cc-theme-classic cc-bottom cc-color-override-688238583 " role="dialog" style=""><!--googleoff: all--><span class="cc-message" id="cookieconsent:desc">This website uses cookies to ensure you get the best experience on our website. <a aria-label="learn more about cookies" class="cc-link" href="http://cookiesandyou.com" role="button" tabindex="0" target="_blank">Learn more</a></span><div class="cc-compliance"><a aria-label="dismiss cookie message" class="cc-btn cc-dismiss" role="button" tabindex="0">Got it!</a></div><!--googleon: all--></div>
# <div class="navbar navbar-inverse navbar-fixed-top" role="navigation" style="z-index: 1000;">
# <div class="container">
# <div class="navbar-header">
# <button class="navbar-toggle" data-target=".navbar-collapse" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <a class="navbar-brand" href="https://www.stogierate.com/"><span style="color: #b18412">Stogie</span><span style="color: #b0a386">Rate</span><span style="color: #7d745f">.com</span></a>
# </div>
# <div class="navbar-collapse collapse" style="white-space: nowrap;">
# <ul class="nav navbar-nav">
# <li class=""><a href="/">Home</a></li>
# <li class="active"><a href="/Cigars">Cigars</a></li>
# <li class=""><a href="/StogieFresh">Cigar Education</a></li>
# <li class="dropdown ">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">More <b class="caret"></b></a>
# <ul class="dropdown-menu">
# <li><a href="/ReviewArchive/newest">Review Archive</a></li>
# <li class="divider"></li>
# <li><a href="/Contact">Contact</a></li>
# <li class="divider"></li>
# <li class="dropdown-header">Join</li>
# <li><a href="/LearnMore">Features</a></li>
# <li><a href="/Signup">Sign Up</a></li>
# </ul>
# </li>
# </ul>
# <form class="srTopNavForm navbar-form navbar-right" role="form" target="SignIn.aspx">
# <div class="form-group">
# <input autocomplete="off" class="form-control" id="signInId" placeholder="Email or screen name" type="text"/>
# </div>
# <button class="btn btn-success" id="btnMasterSignIn" onclick="SR_redirToLogin($('#signInId').val()); return false;">Sign in</button>
# </form>
# </div>
# <!--/.navbar-collapse -->
# </div>
# </div>
# <div id="srBanner" style="height: 180px;">
# <div class="srSunBurst">
#
#             </div>
# <div class="srBannerBand">
# <div style="width: 201px; height: 186px; margin-top: -58px; margin-left: auto; margin-right: auto;">
# <a href="/"><img alt="StogieRate.com logo" src="https://d8e2s4jrdbvb2.cloudfront.net/Images/Skin1/logo_large.png" style="width: 201px; height: 186px;"/></a>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#     SR_onStartup.push(function () {
#         'use strict';
#         $('#srNavBtn').click(function () {
#             if ($($(this).data('target')).hasClass('in')) {
#                 $('#srBanner').show();
#             } else {
#                 $('#srBanner').hide();
#             }
#         });
#
#     });
#     </script>
# <div class="container">
# <div class="srContainer">
# <script>
#         function SR_RecordAd(cat, lbl, val) {
#             StogieRate.Events.view(cat, lbl, val);
#         }
#         function SR_HomeAdClick(ref) {
#             StogieRate.Events.click('AD_HOME', 'BANNER', ref);
#         }
#     </script><div id="">
# <div class="text-muted text-center" style="margin: 20px;">StogieRate.com Sponsors</div><div class="row">
# <div class="col-sm-3 col-xs-6 text-center"><a href="http://caocigars.com/the-lineup/new-age/flathead/" onclick="SR_HomeAdClick(2016030102);" rel="noopener noreferrer" target="_blank"><img alt="CAO Flathead Cigar" src="//www.stogierate.com/Images/Ads/CAO-Flathead-Cigar.jpg" style="padding-bottom: 10px;" title="CAO Flathead Cigar"/></a></div>
# <script type="text/javascript">SR.appendStartup(function () {
#                         StogieRate.Events.view('AD_HOME','BANNER','2016030102');
#             });</script><div class="col-sm-3 col-xs-6 text-center"><a href="http://macanudo.com/inspirado/?utm_source=StogieRate&amp;utm_medium=Banner&amp;utm_content=600x200&amp;utm_campaign=Inspirado" onclick="SR_HomeAdClick(2016050401);" rel="noopener noreferrer" target="_blank"><img alt="Experience the World Through the Eyes of an Icon" src="//www.stogierate.com/Images/Ads/Inspirado-Cigar.jpg" style="padding-bottom: 10px;" title="Experience the World Through the Eyes of an Icon"/></a></div>
# <script type="text/javascript">SR.appendStartup(function () {
#                         StogieRate.Events.view('AD_HOME','BANNER','2016050401');
#             });</script><div class="col-sm-3 col-xs-6 text-center"><a href="https://www.cigarworld.com/products/partagas/partagas-ramon-y-ramon/?utm_source=Stogiefresh.info&amp;utm_medium=Banner&amp;utm_content=120x120&amp;utm_campaign=ramonyramon" onclick="SR_HomeAdClick(2016081101);" rel="noopener noreferrer" target="_blank"><img alt="Partagas Ramon y Ramon" src="//www.stogierate.com/Images/Ads/Partagas_Ramon_y_Ramon.png" style="padding-bottom: 10px;" title="Partagas Ramon y Ramon"/></a></div>
# <script type="text/javascript">SR.appendStartup(function () {
#                         StogieRate.Events.view('AD_HOME','BANNER','2016081101');
#             });</script><div class="col-sm-3 col-xs-6 text-center"><a href="http://www.punchcigars.com/yeti-football/?utm_source=stogiefresh.info&amp;utm_medium=banner&amp;utm_content=120x120&amp;utm_campaign=punchff" onclick="SR_HomeAdClick(2016090101);" rel="noopener noreferrer" target="_blank"><img alt="Punch Yeti Football" src="//www.stogierate.com/Images/Ads/Punch-Yeti-Football.png" style="padding-bottom: 10px;" title="Punch Yeti Football"/></a></div>
# <script type="text/javascript">SR.appendStartup(function () {
#                         StogieRate.Events.view('AD_HOME','BANNER','2016090101');
#             });</script></div></div>
# <ul class="breadcrumb">
# <li><a href="/" id="home">Home</a></li>
# <li class="active"><a href="/Cigars">Browse</a></li>
# <li class="text-muted">All Brands</li>
# </ul>
# <a id="nav_top"></a>
# <h2>Browsing 515 Cigar Brands <button class="btn btn-link" data-target="#browseSearch" data-toggle="collapse" onclick="return false;">
#             Or search with keywords <i class="glyphicon glyphicon-search"></i></button>
# </h2>
# <div class="collapse" id="browseSearch">
# <div class="well">
# <div class="row">
# <div class="col-sm-12">
# <span class="input-group input-group-lg">
# <input class="form-control" id="txtSearch" placeholder="Enter keywords" type="text" value=""/>
# <span class="input-group-btn">
# <button class="btn btn-primary" id="btnSearch" type="submit"><i class="glyphicon glyphicon-search"></i> Search</button>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# <ul class="pagination">
# <li><a class="srBrandNav" href="#A">A</a></li>
# <li><a class="srBrandNav" href="#B">B</a></li>
# <li><a class="srBrandNav" href="#C">C</a></li>
# <li><a class="srBrandNav" href="#D">D</a></li>
# <li><a class="srBrandNav" href="#E">E</a></li>
# <li><a class="srBrandNav" href="#F">F</a></li>
# <li><a class="srBrandNav" href="#G">G</a></li>
# <li><a class="srBrandNav" href="#H">H</a></li>
# <li><a class="srBrandNav" href="#I">I</a></li>
# <li><a class="srBrandNav" href="#J">J</a></li>
# <li><a class="srBrandNav" href="#K">K</a></li>
# <li><a class="srBrandNav" href="#L">L</a></li>
# <li><a class="srBrandNav" href="#M">M</a></li>
# <li><a class="srBrandNav" href="#N">N</a></li>
# <li><a class="srBrandNav" href="#O">O</a></li>
# <li><a class="srBrandNav" href="#P">P</a></li>
# <li><a class="srBrandNav" href="#Q">Q</a></li>
# <li><a class="srBrandNav" href="#R">R</a></li>
# <li><a class="srBrandNav" href="#S">S</a></li>
# <li><a class="srBrandNav" href="#T">T</a></li>
# <li><a class="srBrandNav" href="#U">U</a></li>
# <li><a class="srBrandNav" href="#V">V</a></li>
# <li><a class="srBrandNav" href="#W">W</a></li>
# <li><a class="srBrandNav" href="#X">X</a></li>
# <li><a class="srBrandNav" href="#Y">Y</a></li>
# <li><a class="srBrandNav" href="#Z">Z</a></li>
# </ul>
# <div class="row"><div class="col-sm-5"><p><b><a href="/Cigars/1502%20Cigars">1502 Cigars</a></b> (21)</p></div><div class="col-sm-5"><p><b><a href="/Cigars/1876%20Reserve">1876 Reserve</a></b> (4)</p></div></div><div class="row"><div class="col-sm-5"><p><b><a href="/Cigars/1881">1881</a></b> (4)</p></div><div class="col-sm-5"><p><b><a href="/Cigars/3x3">3x3</a></b> (3)</p></div></div><div class="row"><div class="col-sm-5"><p><b><a href="/Cigars/4x4">4x4</a></b> (5)</p></div><div class="col-sm-5"><p><b><a href="/Cigars/5%20Vegas">5 Vegas</a></b> (51)</p></div></div><div class="row"><div class="col-sm-5"><p><b><a href="/Cigars/601%20by%20Espinosa%20Cigars">601 by Espinosa Cigars</a></b> (19)</p></div><div class="col-sm-5"><p><b><a href="/Cigars/601%20Series%20(2006)">601 Series (2006)</a></b> (21)</p></div></div><div class="row"><div class="col-sm-5"><p><b><a href="/Cigars/7-20-4%20Cigars%20by%20K.A.%20Kendall">7-20-4 Cigars by K.A. Kendall</a></b> (16)</p></div><div class="col-sm-5"><p><b><a href="/Cigars/777%20by%20J.%20Fuego">777 by J. Fuego</a></b> (14)</p></div></div><div class="row"><div class="col-sm-5"><p><b><a href="/Cigars/90%20Miles%20by%20Flor%20de%20Gonzalez">90 Miles by Flor de Gonzalez</a></b> (4)</p></div></div><div style="height: 30px;"><a id="A"></a></div><h3>A</h3><hr/><div class="row"><div class="col-sm-5"><p><b><a href="/Cigars/A.%20Fernandez">A. Fernandez</a></b> (4)</p></div><div class="col-sm-5"><p><b><a href="/Cigars/A.%20Flores">A. Flores</a></b> (9)</p></div></div><div class="row"><div class="col-sm-5"><p><b><a href="/Cigars/A.%20Turrent">A. Turrent</a></b> (17)</p></div><div class="col-sm-5"><p><b><a href="/Cigars/A.J.%20Fernandez%20Cigars">A.J. Fernandez Cigars</a></b> (15)</p></div></div><div class="row"><div class="col-sm-5"><p><b><a href="/Cigars/Abam">Abam</a></b> (14)</p></div><div class="col-sm-5"><p><b><a href="/Cigars/Acid%20by%20Drew%20Estate">Acid by Drew Estate</a></b> (32)</p></div></div><div class="row"><div class="col-sm-5"><p><b><a href="/Cigars/Acme%20Cigar%20Company">Acme Cigar Company</a></b> (10)</p></div><div class="col-sm-5"><p><b><a href="/Cigars/Adan%20y%20Eva">Adan y Eva</a></b> (37)</p></div></div><div class="row"><div class="col-sm-5"><p><b><a href="/Cigars/Adrian%27s">Adrian's</a></b> (15)</p></div><div class="col-sm-5"><p><b><a href="/Cigars/Aging%20Room%20by%20Boutique%20Blends">Aging Room by Boutique Blends</a></b> (32)</p></div></div><div class="row"><div class="col-sm-5"><p><b><a href="/Cigars/Aguila%20Brevas">Aguila Brevas</a></b> (5)</p></div><div class="col-sm-5"><p><b><a href="/Cigars/Aida">Aida</a></b> (10)</p></div></div><div class="row"><div class="col-sm-5"><p><b><a href="/Cigars/AKA%20Cigars">AKA Cigars</a></b> (25)</p></div><div class="col-sm-5"><p><b><a href="/Cigars/Alameda">Alameda</a></b> (4)</p></div></div><div class="row"><div class="col-sm-5"><p><b><a href="/Cigars/Alcazar">Alcazar</a></b> (5)</p></div><div class="col-sm-5"><p><b><a href="/Cigars/Alec%20Bradley">Alec Bradley</a></b> (178)</p></div></div><div class="row"><div class="col-sm-5"><p><b><a href="/Cigars/All%20Americas">All Americas</a></b> (4)</p></div><div class="col-sm-5"><p><b><a href="/Cigars/Alonso%20Menendez">Alonso Menendez</a></b> (4)</p></div></div><div class="row"><div class="col-sm-5"><p><b><a href="/Cigars/Alpha">Alpha</a></b> (15)</p></div><div class="col-sm-5"><p><b><a href="/Cigars/Ambos%20Mundos%20by%20Tatuaje">Ambos Mundos by Tatuaje</a></b> (6)</p></div></div><div class="row"><div class="col-sm-5"><p><b><a href="/Cigars/American%20Stogies">American Stogies</a></b> (12)</p></div><div class="col-sm-5"><p><b><a href="/Cigars/Andros">Andros</a></b> (10)</p></div></div><div class="row"><div class="col-sm-5"><p><b><a href="/Cigars/Angelenos">Angelenos</a></b> (5)</p></div><div class="col-sm-5"><p><b><a href="/Cigars/Anoranzas">Anoranzas</a></b> (4)</p></div></div><div class="row"><div class="col-sm-5"><p><b><a href="/Cigars/Antillian">Antillian</a></b> (7)</p></div><div class="co ...
# </div>
# </div>
# <link href="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.0.3/cookieconsent.min.css" rel="stylesheet" type="text/css"/>
# <script src="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.0.3/cookieconsent.min.js"></script>
# <script>
# window.addEventListener("load", function(){
# window.cookieconsent.initialise({
#   "palette": {
#     "popup": {
#       "background": "#000"
#     },
#     "button": {
#       "background": "#f1d600"
#     }
#   },
#   "theme": "classic"
# })});
# </script>
# <script src="/bundle/shared?v=RRbxC5O2k_L9Q8WSafGSoUkQc8Y3ryWpemdPyFmqqCE1"></script>
# <script src="/bundle/site?v=CuouQkXidf7g_3kijttrqlK-AjfSEnAt7HLKa_Fq1Ew1"></script>
# <script src="/bundle/events?v=cDHj5Gko4yKp7SV9k5degOTucRfxhdjmJv1NrCgkmR81"></script>
# <script type="text/javascript">
#         StogieRate.Events.useGA(_gaq);
#     </script>
# <script id="adListNode" src="/API/Ads/callback=StogieRate.Ads.render" type="text/javascript"></script>
# <script type="text/javascript">
#     $(document).ready(function () {
#         var i, len;
#
#         len = SR_onStartup.length;
#         for (i = 0; i &lt; len; i++) {
#             try {
#                 SR_onStartup[i]();
#             } catch (e) {
#                 console.error("Error while running SR startup scripts: " + e.message);
#             }
#         }
#     });
#     </script>
# <script type="text/javascript">
#         SR_onStartup.push(function () {
#             var searchUrl = '/Search?terms=PLACEHOLDER&amp;returnUrl=%2FCigars&amp;httproute=True';
#             var doCigarSearch = function () {
#                 var searchTerms, searchBox, brandTerm;
#                 searchBox = $('#txtSearch');
#                 searchTerms = encodeURIComponent(searchBox.val());
#                 searchUrl = searchUrl.replace("PLACEHOLDER", searchTerms);
#                 window.location.href = searchUrl;
#             };
#
#             $('#txtSearch').keypress(function (event) {
#                 if (event.which === 13) {
#                     event.preventDefault();
#                     doCigarSearch();
#                 }
#             });
#
#             $('#btnSearch').on('click', function () {
#                 $(this).blur();
#                 doCigarSearch();
#                 return false;
#             });
#         });
# </script>
# <div class="lightboxOverlay" id="lightboxOverlay" style="display: none;"></div><div class="lightbox" id="lightbox" style="display: none;"><div class="lb-outerContainer"><div class="lb-container"><img class="lb-image" src=""/><div class="lb-nav"><a class="lb-prev" href=""></a><a class="lb-next" href=""></a></div><div class="lb-loader"><a class="lb-cancel"></a></div></div></div><div class="lb-dataContainer"><div class="lb-data"><div class="lb-details"><span class="lb-caption"></span><span class="lb-number"></span></div><div class="lb-closeContainer"><a class="lb-close"></a></div></div></div></div></body></html>
